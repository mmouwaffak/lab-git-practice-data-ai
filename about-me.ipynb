# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Meriem"
reason = "I pursue AI/Data Analytics to pilot organisations, turning educational and cultural complexity into measurable signals, prioritising resources, and model risks effectively."
fun_fact = "fashion sewing is my passion, I prototype ideas in fabric"

print(f"Hi! My name is {name}. \n I’m excited to learn because {reason}. \n A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Meriem.
#  I’m excited to learn because I pursue AI/Data Analytics to pilot organisations, turning educational and cultural complexity into measurable signals, prioritising resources, and model risks effectively..
#  A fun fact about me is: fashion sewing is my passion, I prototype ideas in fabric.
